# %%
import pandas as pd
from pymongo import MongoClient
import mysql.connector

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="miguel",
  password="miguel",
  database="tiktok_qatar2022"
)

# %%
mycursor = mydb.cursor()
mysql = "SELECT * FROM qatar2022_1644120937954"
mycursor.execute(mysql)
myresult = mycursor.fetchall()

# %%
CLIENT = MongoClient("mongodb+srv://miguel:miguel@cluster0.ed8kj.mongodb.net/test") 
try:
    CLIENT.admin.command('ismaster')
    print('MongoDB connection: Success')
except ConnectionFailure as cf:
    print('MongoDB connection: failed', cf)
    
DBS = CLIENT.get_database('tiktok_qatar2022')  
db = DBS.MySql
# Out:
# MongoDB connection: Success

# %%
for row in myresult:
    doc={} 
    doc['_id']=row[0]
    doc['title'] =row[1]
    doc['body'] = row[2]
    doc['created_at']=row[3]
    doc['updated_at'] = row[4]
    doc['user_id'] =  row[5]
    doc['category_id'] = row[6]
    try:
        print(doc)
        db.insert_one(doc)
        print("guardado exitosamente")
    except Exception as e:    
        print("no se pudo grabar:" + str(e))
# Out:
# {'_id': 'id', 'title': 'secretID', 'body': 'text', 'created_at': 'createTime', 'updated_at': 'authorMeta.id', 'user_id': 'authorMeta.secUid', 'category_id': 'authorMeta.name'}
# guardado exitosamente
# {'_id': '7031910840064396550', 'title': '7031910840064396550', 'body': '¡A casi 1 año para #Qatar2022! Súmate al desafío 365: 3 jueguitos con la cabeza + 6 con la rodilla + 5 con los pies ⚽ ¿Puedes? ¡Sigue el ritmo!', 'created_at': '1637244328', 'updated_at': '7007441425663771654', 'user_id': 'MS4wLjABAAAA5hqPQ3zXJlCADOlGJXgtPrCnMT7ayPgXJCf39mWi-snSLUr-pcLASUS77yryy-hK', 'category_id': 'roadto2022es'}
# guardado exitosamente
# {'_id': '7049136647648054533', 'title': '7049136647648054533', 'body': '5 outfits para estar en Qatar ??? ? @Dohabibis #qatar #qatar2022 #mundial', 'created_at': '1641255024', 'updated_at': '7007441425663771654', 'user_id': 'MS4wLjABAAAA5hqPQ3zXJlCADOlGJXgtPrCnMT7ayPgXJCf39mWi-snSLUr-pcLASUS77yryy-hK', 'category_id': 'roadto2022es'}
# guardado exitosamente
# ...
