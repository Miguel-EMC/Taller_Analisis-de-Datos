# %%
import pymongo
import pandas as pd
from pymongo import MongoClient

# %%
client = pymongo.MongoClient('mongodb://localhost:27017')

# %%
df = pd.read_csv("D:\Miguel\Documents\Analisis\Tiktok\Taller/Qatar2022_1644780131242.csv")

# %%
df.head()
# Out:
#                     id             secretID  \
# 0  7031910840064396550  7031910840064396550
# 1  7049136647648054533  7049136647648054533
# 2  7056810441825078533  7056810441825078533
# 3  7055045916344028421  7055045916344028421
# 4  7050175294795222278  7050175294795222278
#
#                                                 text  createTime  \
# 0  ¡A casi 1 año para #Qatar2022! Súmate al desaf...  1637244328
# 1  5 outfits para estar en Qatar 👚👕😉 📲 @Dohabibis...  1641255024
# 2  Características de #Qatar2022 #parati #fyp #fú...  1643041718
# 3  Un tiro dolía menos 😥. #qatar2022 #mundial #ar...  1642630883
# 4  El verdadero objetivo #messi #qatar2022 #copad...  1641496852
#
#          authorMeta.id                                  authorMeta.secUid  \
# 0  7007441425663771654  MS4wLjABAAAA5hqPQ3zXJlCADOlGJXgtPrCnMT7ayPgXJC...
# 1  7007441425663771654  MS4wLjABAAAA5hqPQ3zXJlCADOlGJXgtPrCnMT7ayPgXJC...
# 2  6920594083463496709  MS4wLjABAAAAs4iK8-AqRhZWQlQf_iIkEkdW04hjTz07iC...
# ...

# %%
data = df.to_dict(orient="records")

# %%
db = client["Qatar2022"]

# %%
db.Qatar2022_1644780131242.insert_many(data)
